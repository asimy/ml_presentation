# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
hwdata = pd.read_csv('SOCR-HeightWeight.csv')

X = hwdata['height']

y = hwdata['weight']

plt.plot(X[:100],y[:100], 'x')
